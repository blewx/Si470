# %%
# Import packages
import pandas as pd
import os
import os.path as osp
import numpy as np
import json
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Paths to directories
currentdir = os.getcwd()
inputdir = osp.realpath(osp.join(currentdir, '..', 'inputData'))
moogaldir = osp.realpath(osp.join(currentdir, '..', 'MOOGALdefs'))
outputdir = osp.realpath(osp.join(currentdir, '..', 'outputData'))

# %%
current_date = datetime.today().strftime('%y%m%d')

# %%
# Load files
economic = pd.read_csv(outputdir + '/M24_economic_activity_' + current_date + '.csv')
TUS = pd.read_csv(outputdir + '/M24_TUS_and_youth_' + current_date + '.csv')

GDP = pd.read_csv(inputdir + '/gdp_per_capita.csv').set_index('country_iso3')
GDP = GDP.dropna(axis=0, how='all')

indexfile = pd.read_csv(inputdir + '/indexfile.csv').set_index(['countryISO3'])
indexfile = indexfile[indexfile['include'] == 1.0]

demography = pd.read_csv(inputdir + '/demography.csv').set_index(['countryISO3','year'])

# %%
# WPAC reclassified, remove empty rows
economic = economic[economic['region_code'] != 'WPAC']

# Rename TUS subcat of organization to allocation, and things to artifacts
TUS['subcategory'] = TUS['subcategory'].str.replace('organization', 'allocation')
TUS['subcategory'] = TUS['subcategory'].str.replace('things', 'artifacts')
economic['subcategory'] = economic['subcategory'].str.replace('things', 'artifacts')

# %%
categories = ['Experience oriented', 'Somatic maintenance', 'Organization', 'Technosphere modification',             
              'Somatic maintenance', 'Deliberate neural restructuring', 'Nonfood provision', 'Food provision', 
              'Somatic maintenance', 'Technosphere modification', 'Maintenance of surroundings', 
              'Experience oriented', 'Nonfood provision', 'Experience oriented', 'Organization', 'Organization', 
              'Experience oriented', 'Food provision', 'Food provision', 'Deliberate neural restructuring', 
              'Somatic maintenance', 'Experience oriented', 'Technosphere modification', 
              'Maintenance of surroundings']
cat_num = [0,1,2,3,4,5...]

subcategories = ['Active recreation','Health care','Allocation','Buildings','Physical child care',
                'Schooling & research','Energy','Food growth & collection','Hygiene & grooming','Infrastructure',
                'Inhabited environment','Interactive','Materials','Meals','Human transportation',
                'Material transportation','Passive','Food preparation','Food processing','Religious practice',
                'Sleep & bedrest','Social','Artifacts','Waste management']

# %%
# Compute global human day

TUS_all = TUS[['countryISO3','subcategory','hoursPerDay','uncertainty','dataStatus']]
economic_all = economic.rename(columns={\
        'hoursPerDay':'hoursPerDayEconomic','uncertainty':'uncertaintyEconomic','dataStatus':'dataStatusEconomic'})

all_data = economic_all.merge(TUS_all, on=['countryISO3','subcategory']).set_index('subcategory')
group = all_data.groupby('countryISO3')

all_data_list = []
all_data_econ_list = []

for name, grp in group:
    economic_worktime = grp['hoursPerDayEconomic'].sum()
    TUS_work_employment = grp.loc['work_employment']['hoursPerDay']
    
    # Replace M24 subcategory codenames with proper publication names
    grp = grp.drop(['work_employment','work_other'], axis=0)
    grp['Subcategory'] = subcategories
    grp = grp.set_index('Subcategory')
    
    # Assume TUS is correct estimation of total working time, scale economic working time to fit (see SI for detail)
    worktime_ratio = TUS_work_employment / economic_worktime
    
    # Add the worktime ratio to uncertainty in economic working time
    grp['uncertaintyEconomic'] = grp['uncertaintyEconomic'] + abs(1 - worktime_ratio)**2 * \
                                                                        grp['hoursPerDayEconomic']**2
    
    grp['hoursPerDayEconomic'] = grp['hoursPerDayEconomic'].apply(lambda x: x * worktime_ratio)
    
    # Combine TUS with economic
    grp['hoursPerDayCombined'] = grp['hoursPerDay'] + grp['hoursPerDayEconomic']
    # Uncertainty is in units of variance
    grp['uncertaintyCombined'] = grp['uncertainty'] + grp['uncertaintyEconomic'] 
    
    all_data_list.append(grp[['countryISO3','region_code','population','hoursPerDayCombined',\
                              'uncertaintyCombined', 'dataStatus','dataStatusEconomic']]) 
    
    all_data_econ_list.append(grp[['countryISO3','region_code','population','hoursPerDayEconomic',\
                                   'uncertaintyEconomic']])

# Global Human Day
all_data_combined = pd.concat(all_data_list)

total_pop = all_data_combined['population'].unique().sum()

person_hours = all_data_combined['hoursPerDayCombined'] * all_data_combined['population']
global_M24_hours = (person_hours / total_pop).groupby('Subcategory').sum()

pop_weight = all_data_combined['population'] / total_pop
var_combined = all_data_combined['uncertaintyCombined']

global_M24_uncertainty = (pop_weight**2 * var_combined).groupby('Subcategory').sum()

global_M24_all = pd.DataFrame(global_M24_hours, columns=['hoursPerDay'])
global_M24_all['uncertainty'] = 2*np.sqrt(global_M24_uncertainty)

# Global Economic Activity
all_data_econ_combined = pd.concat(all_data_econ_list)

person_hours = all_data_econ_combined['hoursPerDayEconomic'] * all_data_econ_combined['population']
global_M24_hours = (person_hours / total_pop).groupby('Subcategory').sum()

var_combined_econ = all_data_econ_combined['uncertaintyEconomic']
pop_weight = all_data_econ_combined['population'] / total_pop

global_M24_uncertainty = (pop_weight**2 * var_combined_econ).groupby('Subcategory').sum()

global_M24_econ_all = pd.DataFrame(global_M24_hours, columns=['hoursPerDay'])
global_M24_econ_all['uncertainty'] = 2*np.sqrt(global_M24_uncertainty)

# %%
difference = (global_M24_all['hoursPerDay'].sum() - 24)
initial_hours = global_M24_all['hoursPerDay'].sum()

adj = global_M24_all['hoursPerDay'].apply(lambda t: t - (difference * t / initial_hours))
global_M24_all['hoursPerDay'] = adj

global_M24_all = round(global_M24_all,2)
global_M24_econ_all = round(global_M24_econ_all,2)
all_data_combined['hoursPerDayCombined'] = round(all_data_combined['hoursPerDayCombined'],2)

# %%
# Save out main GHD estimate
global_M24_all.to_csv(outputdir + '/global_human_day_' + current_date + '.csv')
global_M24_econ_all.to_csv(outputdir + '/global_economic_activity_' + current_date + '.csv')

# Save out the by-country combined data
all_data_combined.to_csv(outputdir + '/all_countries_' + current_date + '.csv')

# %%
a = grp[['countryISO3','region_code','population','hoursPerDayCombined',\
                              'uncertaintyCombined', 'dataStatus','dataStatusEconomic']]
a['category'] = categories
a = a.sort_values(by='category')
a.reset_index().set_index(['category','Subcategory'])
# Out:
# /var/folders/17/9w7y4lgn3x9_7_5v8d4g1t440000gn/T/ipykernel_93954/3246302909.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['category'] = categories
#                                                          countryISO3  \
# category                        Subcategory
# Deliberate neural restructuring Religious practice               ZWE
#                                 Schooling & research             ZWE
# Experience oriented             Active recreation                ZWE
#                                 Social                           ZWE
#                                 Passive                          ZWE
#                                 Meals                            ZWE
#                                 Interactive                      ZWE
# Food provision                  Food growth & collection         ZWE
#                                 Food processing                  ZWE
#                                 Food preparation                 ZWE
# Maintenance of surroundings     Waste management                 ZWE
#                                 Inhabited environment            ZWE
# Nonfood provision               Materials                        ZWE
#                                 Energy                           ZWE
# Organization                    Human transportation             ZWE
#                                 Allocation                       ZWE
#                                 Material transportation          ZWE
# Somatic maintenance             Physical child care              ZWE
#                                 Hygiene & grooming               ZWE
#                                 Sleep & bedrest                  ZWE
#                                 Health care                      ZWE
# Technosphere modification       Artifacts                        ZWE
#                                 Buildings                        ZWE
#                                 Infrastructure                   ZWE
#
#                                                          region_code  \
# category                        Subcategory
# Deliberate neural restructuring Religious practice              AF_E
#                                 Schooling & research            AF_E
# Experience oriented             Active recreation               AF_E
#                                 Social                          AF_E
#                                 Passive                         AF_E
#                                 Meals                           AF_E
#                                 Interactive                     AF_E
# Food provision                  Food growth & collection        AF_E
#                                 Food processing                 AF_E
#                                 Food preparation                AF_E
# Maintenance of surroundings     Waste management                AF_E
#                                 Inhabited environment           AF_E
# Nonfood provision               Materials                       AF_E
#                                 Energy                          AF_E
# Organization                    Human transportation            AF_E
#                                 Allocation                      AF_E
#                                 Material transportation         AF_E
# Somatic maintenance             Physical child care             AF_E
#                                 Hygiene & grooming              AF_E
#                                 Sleep & bedrest                 AF_E
#                                 Health care                     AF_E
# Technosphere modification       Artifacts                       AF_E
#                                 Buildings                       AF_E
#                                 Infrastructure                  AF_E
#
#                                                           population  \
# category                        Subcategory
# Deliberate neural restructuring Religious practice        14645473.0
#                                 Schooling & research      14645473.0
# Experience oriented             Active recreation         14645473.0
#                                 Social                    14645473.0
#                                 Passive                   14645473.0
#                                 Meals                     14645473.0
#                                 Interactive               14645473.0
# Food provision                  Food growth & collection  14645473.0
#                                 Food processing           14645473.0
#                                 Food preparation          14645473.0
# Maintenance of surroundings     Waste management          14645473.0
#                                 Inhabited environment     14645473.0
# Nonfood provision               Materials                 14645473.0
#                                 Energy                    14645473.0
# Organization                    Human transportation      14645473.0
#                                 Allocation                14645473.0
#                                 Material transportation   14645473.0
# Somatic maintenance             Physical child care       14645473.0
#                                 Hygiene & grooming        14645473.0
#                                 Sleep & bedrest           14645473.0
#                                 Health care               14645473.0
# Technosphere modification       Artifacts                 14645473.0
#                                 Buildings                 14645473.0
#                                 Infrastructure            14645473.0
#
#                                                           hoursPerDayCombined  \
# category                        Subcategory
# Deliberate neural restructuring Religious practice                   0.152215
#                                 Schooling & research                 1.132753
# Experience oriented             Active recreation                    0.387895
#                                 Social                               0.930667
#                                 Passive                              2.248096
#                                 Meals                                1.884815
#                                 Interactive                          1.103432
# Food provision                  Food growth & collection             1.239664
#                                 Food processing                      0.116713
#                                 Food preparation                     0.725863
# Maintenance of surroundings     Waste management                     0.009753
#                                 Inhabited environment                0.886220
# Nonfood provision               Materials                            0.167892
#                                 Energy                               0.015333
# Organization                    Human transportation                 0.980924
#                                 Allocation                           0.751081
#                                 Material transportation              0.273291
# Somatic maintenance             Physical child care                  0.296733
#                                 Hygiene & grooming                   1.069250
#                                 Sleep & bedrest                      8.934335
#                                 Health care                          0.364386
# Technosphere modification       Artifacts                            0.177725
#                                 Buildings                            0.131159
#                                 Infrastructure                       0.019898
#
#                                                           uncertaintyCombined  \
# category                        Subcategory
# Deliberate neural restructuring Religious practice                   0.153439
#                                 Schooling & research                 0.285277
# Experience oriented             Active recreation                    0.100182
#                                 Social                               0.594238
#                                 Passive                              1.815564
#                                 Meals                                1.262100
#                                 Interactive                          0.350849
# Food provision                  Food growth & collection             0.162867
#                                 Food processing                      0.009317
#                                 Food preparation                     0.228542
# Maintenance of surroundings     Waste management                     0.000673
#                                 Inhabited environment                0.226303
# Nonfood provision               Materials                            0.003736
#                                 Energy                               0.002210
# Organization                    Human transportation                 1.038907
#                                 Allocation                           0.157574
#                                 Material transportation              0.076691
# Somatic maintenance             Physical child care                  0.065318
#                                 Hygiene & grooming                   1.022471
#                                 Sleep & bedrest                      2.614993
#                                 Health care                          0.965682
# Technosphere modification       Artifacts                            0.016713
#                                 Buildings                            0.012903
#                                 Infrastructure                       0.000231
#
#                                                             dataStatus  \
# category                        Subcategory
# Deliberate neural restructuring Religious practice        interpolated
#                                 Schooling & research      interpolated
# Experience oriented             Active recreation         interpolated
#                                 Social                    interpolated
#                                 Passive                   interpolated
#                                 Meals                     interpolated
#                                 Interactive               interpolated
# Food provision                  Food growth & collection  interpolated
#                                 Food processing           interpolated
#                                 Food preparation          interpolated
# Maintenance of surroundings     Waste management          interpolated
#                                 Inhabited environment     interpolated
# Nonfood provision               Materials                 interpolated
#                                 Energy                    interpolated
# Organization                    Human transportation      interpolated
#                                 Allocation                interpolated
#                                 Material transportation   interpolated
# Somatic maintenance             Physical child care       interpolated
#                                 Hygiene & grooming        interpolated
#                                 Sleep & bedrest           interpolated
#                                 Health care               interpolated
# Technosphere modification       Artifacts                 interpolated
#                                 Buildings                 interpolated
#                                 Infrastructure            interpolated
#
#                                                          dataStatusEconomic
# category                        Subcategory
# Deliberate neural restructuring Religious practice                 observed
#                                 Schooling & research               observed
# Experience oriented             Active recreation                  observed
#                                 Social                             observed
#                                 Passive                            observed
#                                 Meals                              observed
#                                 Interactive                        observed
# Food provision                  Food growth & collection           observed
#                                 Food processing                    observed
#                                 Food preparation                   observed
# Maintenance of surroundings     Waste management                   observed
#                                 Inhabited environment              observed
# Nonfood provision               Materials                          observed
#                                 Energy                             observed
# Organization                    Human transportation               observed
#                                 Allocation                         observed
#                                 Material transportation            observed
# Somatic maintenance             Physical child care                observed
#                                 Hygiene & grooming                 observed
#                                 Sleep & bedrest                    observed
#                                 Health care                        observed
# Technosphere modification       Artifacts                          observed
#                                 Buildings                          observed
#                                 Infrastructure                     observed
